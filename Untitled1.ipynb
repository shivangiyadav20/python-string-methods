# %%
# 1
a="Hello"
b="world"
result=a +""+ b
print(result)
# Out:
# Helloworld

# %%
#2
#using +
a="Hello"
b="world"
print(a +""+ b)

#using Join
words=["Helloo","world"]
print("".join(words))
# Out:
# Helloworld
# Hellooworld

# %%
#3
a="Python"
print(a[0])
print(a[1])
print(a[2])
# Out:
# P
# y
# t

# %%
#4
a="Python"
print(len(a))
# Out:
# 6

# %%
#5
a="Python"
print(a.upper())
# Out:
# PYTHON

# %%
#6
a="Python"
print(a.lower())
# Out:
# python

# %%
#7
a="i like python"
print(a.replace("python","Java"))
# Out:
# i like Java

# %%
#8
a="ram,shyam,radha"
result=a.split(",")
print(result)
# Out:
# ['ram', 'shyam', 'radha']

# %%
#9
a="Hello Python"
print(a.startswith("Hello"))
# Out:
# True

# %%
#10
a="Hello Python"
print(a.endswith("Python"))
# Out:
# True

# %%
#11
a="  Python  "
print(a.strip())
# Out:
# Python

# %%
#12
a="Hello Python"
print(a.find("python"))
# Out:
# -1

# %%
#13
a="ram,shyam,radha,ram,ram"
print(a.count("ram"))
# Out:
# 3

# %%
#14
a="Python"
print(a.isalpha())
# Out:
# True

# %%
#15
a="11"
print(a.isnumeric())
# Out:
# True

# %%
#16
a="python"

if a==a[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Not Palindrome

# %%
#17
a="Python"
reverse=a[::-1]
print(reverse)
# Out:
# nohtyP

# %%
#18
name="Shivangi"
age=22
res="My name is {} and i'm {} years old".format(name,age)
print(res)
# Out:
# My name is Shivangi and i'm 22 years old

# %%
a="Python"
substring=a[0:4]
print(substring)
# Out:
# Pyth

# %%
#20
a="hello Python"
res=a.replace("h","")
print(res)
# Out:
# ello Pyton
